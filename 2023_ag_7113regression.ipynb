# %%
import pandas as pd
import numpy as np

# %%
Maliha= pd.read_csv('soil_data.csv')
Maliha
# Out:
#        fips        lat         lon  elevation  slope1  slope2  slope3  slope4  \
# 0      1001  32.536382  -86.644490         63  0.0419  0.2788  0.2984  0.2497
# 1      1005  31.870670  -85.405456        146  0.0158  0.1868  0.5441  0.2424
# 2      1003  30.659218  -87.746067         52  0.0746  0.4370  0.4415  0.0469
# 3      1007  33.015893  -87.127148         93  0.0144  0.1617  0.3714  0.3493
# 4      1009  33.977448  -86.567246        198  0.0050  0.0872  0.2799  0.3576
# ...     ...        ...         ...        ...     ...     ...     ...     ...
# 3104  56037  41.660339 -108.875676       2085  0.0016  0.0281  0.1763  0.3554
# 3105  56039  44.049321 -110.588102       2564  0.0003  0.0026  0.0166  0.0722
# 3106  56043  43.878831 -107.669052       1417  0.0034  0.0470  0.2331  0.4099
# 3107  56041  41.284726 -110.558947       2327  0.0050  0.2009  0.4063  0.1858
# 3108  56045  43.846213 -104.570020       1276  0.0158  0.1958  0.6160  0.1688
#
# ...

# %%
Maliha.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
Maliha.describe()
# Out:
#                fips          lat          lon    elevation       slope1  \
# count   3109.000000  3109.000000  3109.000000  3109.000000  3109.000000
# mean   30678.538437    38.280052   -91.659790   427.624638     0.054973
# std    14986.018730     4.838634    11.485291   500.158880     0.089873
# min     1001.000000    25.601043  -124.211407    -1.000000     0.000000
# 25%    19045.000000    34.686818   -98.046842   132.000000     0.008300
# 50%    29213.000000    38.328061   -90.181170   272.000000     0.028300
# 75%    46009.000000    41.703590   -83.373303   483.000000     0.068500
# max    56045.000000    48.842653   -67.609354  3561.000000     0.974000
#
#            slope2       slope3       slope4       slope5       slope6  ...  \
# count  3109.00000  3109.000000  3109.000000  3109.000000  3109.000000  ...
# mean      0.29775     0.319991     0.155878     0.053409     0.065323  ...
# std       0.21595     0.167727     0.128400     0.073107     0.125526  ...
# ...

# %%
Maliha.isnull().sum()
# Out:
# fips             0
# lat              0
# lon              0
# elevation        0
# slope1           0
# slope2           0
# slope3           0
# slope4           0
# slope5           0
# slope6           0
# slope7           0
# slope8           0
# aspectN          0
# aspectE          0
# aspectS          0
# aspectW          0
# aspectUnknown    0
# WAT_LAND         0
# NVG_LAND         0
# URB_LAND         0
# GRS_LAND         0
# FOR_LAND         0
# CULTRF_LAND      0
# CULTIR_LAND      0
# CULT_LAND        0
# SQ1              0
# SQ2              0
# SQ3              0
# SQ4              0
# SQ5              0
# SQ6              0
# SQ7              0
# dtype: int64

# %%
duplicates_mask = Maliha.duplicated()
duplicates_mask.sum()
# Out:
# np.int64(0)

# %%
for i in Maliha.columns:
    if(Maliha[i].dtype == 'int64' and (Maliha[i]==0).sum()!=0):
        print(i , Maliha[i].dtype , (Maliha[i]==0).sum())
# Out:
# elevation int64 37
# SQ1 int64 49
# SQ2 int64 49
# SQ3 int64 49
# SQ4 int64 49
# SQ5 int64 49
# SQ6 int64 49
# SQ7 int64 49

# %%
Maliha['elevation'] = Maliha['elevation'].replace( 0, Maliha['elevation'].mean())

# %%
for i in Maliha.columns:
    print(i , Maliha[i].value_counts())
# Out:
# fips fips
# 56045    1
# 1001     1
# 1005     1
# 1003     1
# 1007     1
#         ..
# 1019     1
# 1017     1
# 1015     1
# 1013     1
# 1011     1
# Name: count, Length: 3109, dtype: int64
# lat lat
# 43.846213    1
# 32.536382    1
# 31.870670    1
# 30.659218    1
# 33.015893    1
#             ..
# 34.069515    1
# 32.917943    1
# 33.771706    1
# 31.751667    1
# 32.101759    1
# Name: count, Length: 3109, dtype: int64
# lon lon
# -104.570020    1
# -86.644490     1
# -85.405456     1
# -87.746067     1
# -87.127148     1
#               ..
# -85.654242     1
# -85.391812     1
# -85.822513     1
# -86.681969     1
# -85.717261     1
# Name: count, Length: 3109, dtype: int64
# elevation elevation
# 427.624638     37
# 10.000000      19
# 6.000000       14
# 292.000000     14
# 8.000000       13
#                ..
# 977.000000      1
# 2085.000000     1
# 2564.000000     1
# 1417.000000     1
# 2327.000000     1
# Name: count, Length: 1062, dtype: int64
# slope1 slope1
# ...

# %%
for i in Maliha.columns:
    if(Maliha[i].dtype == 'float64' and (Maliha[i]==0).sum()!=0):
        print(i , Maliha[i].dtype , (Maliha[i]==0).sum())
# Out:
# slope1 float64 63
# slope2 float64 35
# slope3 float64 54
# slope4 float64 82
# slope5 float64 537
# slope6 float64 1257
# slope7 float64 2155
# slope8 float64 2533
# aspectN float64 54
# aspectE float64 54
# aspectS float64 54
# aspectW float64 55
# aspectUnknown float64 35
# WAT_LAND float64 2729
# NVG_LAND float64 2738
# URB_LAND float64 254
# GRS_LAND float64 81
# FOR_LAND float64 266
# CULTRF_LAND float64 659
# CULTIR_LAND float64 250
# CULT_LAND float64 164

# %%
Maliha.columns
# Out:
# Index(['fips', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'slope6', 'slope7', 'slope8', 'aspectN', 'aspectE',
#        'aspectS', 'aspectW', 'aspectUnknown', 'WAT_LAND', 'NVG_LAND',
#        'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND', 'CULTIR_LAND',
#        'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6', 'SQ7'],
#       dtype='object')

# %%
Maliha =Maliha.drop(['slope6','slope7','slope8','NVG_LAND',] , axis = 1)

# %%
Maliha=Maliha.drop('WAT_LAND',axis=1)

# %%
Maliha['slope1'] = Maliha['slope1'].replace( 0, Maliha['slope1'].mean())
Maliha['slope2'] = Maliha['slope2'].replace( 0, Maliha['slope2'].mean())
Maliha['slope3'] = Maliha['slope3'].replace( 0, Maliha['slope3'].mean())
Maliha['slope4'] = Maliha['slope4'].replace( 0, Maliha['slope4'].mean())
Maliha['slope5'] = Maliha['slope5'].replace( 0, Maliha['slope5'].mean())
Maliha['aspectN'] = Maliha['aspectN'].replace( 0, Maliha['aspectN'].mean())
Maliha['aspectE'] = Maliha['aspectE'].replace( 0, Maliha['aspectE'].mean())
Maliha['aspectS'] = Maliha['aspectS'].replace( 0, Maliha['aspectS'].mean())
Maliha['aspectW'] = Maliha['aspectW'].replace( 0, Maliha['aspectW'].mean())
Maliha['aspectUnknown'] = Maliha['aspectUnknown'].replace( 0, Maliha['aspectUnknown'].mean())
Maliha['GRS_LAND'] = Maliha['GRS_LAND'].replace( 0, Maliha['GRS_LAND'].mean())
Maliha['FOR_LAND'] = Maliha['FOR_LAND'].replace( 0, Maliha['FOR_LAND'].mean())
Maliha['CULTRF_LAND'] = Maliha['CULTRF_LAND'].replace( 0, Maliha['CULTRF_LAND'].mean())
Maliha['CULTIR_LAND'] = Maliha['CULTIR_LAND'].replace( 0, Maliha['CULTIR_LAND'].mean())
Maliha['CULT_LAND'] = Maliha['CULT_LAND'].replace( 0, Maliha['CULT_LAND'].mean())

# %%
for i in Maliha.columns:
    print(i , Maliha[i].value_counts())
# Out:
# fips fips
# 56045    1
# 1001     1
# 1005     1
# 1003     1
# 1007     1
#         ..
# 1019     1
# 1017     1
# 1015     1
# 1013     1
# 1011     1
# Name: count, Length: 3109, dtype: int64
# lat lat
# 43.846213    1
# 32.536382    1
# 31.870670    1
# 30.659218    1
# 33.015893    1
#             ..
# 34.069515    1
# 32.917943    1
# 33.771706    1
# 31.751667    1
# 32.101759    1
# Name: count, Length: 3109, dtype: int64
# lon lon
# -104.570020    1
# -86.644490     1
# -85.405456     1
# -87.746067     1
# -87.127148     1
#               ..
# -85.654242     1
# -85.391812     1
# -85.822513     1
# -86.681969     1
# -85.717261     1
# Name: count, Length: 3109, dtype: int64
# elevation elevation
# 427.624638     37
# 10.000000      19
# 6.000000       14
# 292.000000     14
# 8.000000       13
#                ..
# 977.000000      1
# 2085.000000     1
# 2564.000000     1
# 1417.000000     1
# 2327.000000     1
# Name: count, Length: 1062, dtype: int64
# slope1 slope1
# ...

# %%
Maliha.shape
# Out:
# (3109, 27)

# %%
correlation = Maliha.corr()
correlation
# Out:
#                    fips       lat       lon  elevation    slope1    slope2  \
# fips           1.000000  0.141720  0.045691   0.025567 -0.087708 -0.085502
# lat            0.141720  1.000000 -0.191780   0.268131 -0.077033 -0.090280
# lon            0.045691 -0.191780  1.000000  -0.584095  0.004253 -0.056893
# elevation      0.025567  0.268131 -0.584095   1.000000 -0.147754 -0.217622
# slope1        -0.087708 -0.077033  0.004253  -0.147754  1.000000  0.489015
# slope2        -0.085502 -0.090280 -0.056893  -0.217622  0.489015  1.000000
# slope3        -0.060423 -0.175356  0.154176  -0.267442 -0.219092  0.059480
# slope4         0.045778  0.048342  0.157584   0.010434 -0.410284 -0.726788
# slope5         0.121611  0.142845  0.010978   0.233107 -0.252265 -0.606682
# aspectN        0.082760  0.087385 -0.021128   0.255486 -0.492565 -0.796790
# aspectE        0.090638  0.082175  0.026564   0.230625 -0.508388 -0.781817
# ...

# %%
missing_data = Maliha.isnull()

# %%
import matplotlib.pyplot  as plt 
import seaborn  as sns

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
G1 = Maliha.iloc[ : , :12]
G1.shape
# Out:
# (3109, 12)

# %%
G2 = Maliha.iloc[ : ,12:27]
G2.shape
# Out:
# (3109, 15)

# %%
correlation = G1.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
Maliha.columns
# Out:
# Index(['fips', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'aspectN', 'aspectE', 'aspectS', 'aspectW',
#        'aspectUnknown', 'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND',
#        'CULTIR_LAND', 'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6',
#        'SQ7'],
#       dtype='object')

# %%
G1 =G1.drop(['fips','lon','lat','slope2','slope3','slope4','slope5'] , axis = 1)
G1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   elevation  3109 non-null   float64
#  1   slope1     3109 non-null   float64
#  2   aspectN    3109 non-null   float64
#  3   aspectE    3109 non-null   float64
#  4   aspectS    3109 non-null   float64
# dtypes: float64(5)
# memory usage: 121.6 KB

# %%
correlation = G1.corr()
plt.figure(figsize=(18,18))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
Maliha.columns
# Out:
# Index(['fips', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'aspectN', 'aspectE', 'aspectS', 'aspectW',
#        'aspectUnknown', 'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND',
#        'CULTIR_LAND', 'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6',
#        'SQ7'],
#       dtype='object')

# %%
correlation = G2.corr()
plt.figure(figsize=(18,18))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
G2 =G2.drop(['SQ1','SQ3','SQ4'] , axis = 1)
G2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   aspectW        3109 non-null   float64
#  1   aspectUnknown  3109 non-null   float64
#  2   URB_LAND       3109 non-null   float64
#  3   GRS_LAND       3109 non-null   float64
#  4   FOR_LAND       3109 non-null   float64
#  5   CULTRF_LAND    3109 non-null   float64
#  6   CULTIR_LAND    3109 non-null   float64
#  7   CULT_LAND      3109 non-null   float64
#  8   SQ2            3109 non-null   int64
#  9   SQ5            3109 non-null   int64
#  10  SQ6            3109 non-null   int64
#  11  SQ7            3109 non-null   int64
# dtypes: float64(8), int64(4)
# memory usage: 291.6 KB

# %%
correlation = G2.corr()
plt.figure(figsize=(18,18))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
G2 =G2.drop(['SQ5','SQ6'] , axis = 1)
G2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   aspectW        3109 non-null   float64
#  1   aspectUnknown  3109 non-null   float64
#  2   URB_LAND       3109 non-null   float64
#  3   GRS_LAND       3109 non-null   float64
#  4   FOR_LAND       3109 non-null   float64
#  5   CULTRF_LAND    3109 non-null   float64
#  6   CULTIR_LAND    3109 non-null   float64
#  7   CULT_LAND      3109 non-null   float64
#  8   SQ2            3109 non-null   int64
#  9   SQ7            3109 non-null   int64
# dtypes: float64(8), int64(2)
# memory usage: 243.0 KB

# %%
correlation = G2.corr()
plt.figure(figsize=(18,18))
sns.heatmap(correlation, square=True, fmt='.1f', annot=True, 
annot_kws={'size':12})
# Out:
# <Axes: >

# %%
Maliha.shape
# Out:
# (3109, 27)

# %%
Maliha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109 entries, 0 to 3108
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fips           3109 non-null   int64
#  1   lat            3109 non-null   float64
#  2   lon            3109 non-null   float64
#  3   elevation      3109 non-null   float64
#  4   slope1         3109 non-null   float64
#  5   slope2         3109 non-null   float64
#  6   slope3         3109 non-null   float64
#  7   slope4         3109 non-null   float64
#  8   slope5         3109 non-null   float64
#  9   aspectN        3109 non-null   float64
#  10  aspectE        3109 non-null   float64
#  11  aspectS        3109 non-null   float64
#  12  aspectW        3109 non-null   float64
#  13  aspectUnknown  3109 non-null   float64
#  14  URB_LAND       3109 non-null   float64
#  15  GRS_LAND       3109 non-null   float64
#  16  FOR_LAND       3109 non-null   float64
# ...

# %%
Maliha.columns
# Out:
# Index(['fips', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'aspectN', 'aspectE', 'aspectS', 'aspectW',
#        'aspectUnknown', 'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND',
#        'CULTIR_LAND', 'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6',
#        'SQ7'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X = Maliha.drop('CULTRF_LAND', axis=1)
Y = Maliha['CULTRF_LAND']

# %%
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3109 entries, 0 to 3108
# Series name: CULTRF_LAND
# Non-Null Count  Dtype
# --------------  -----
# 3109 non-null   float64
# dtypes: float64(1)
# memory usage: 24.4 KB

# %%
from sklearn.model_selection import train_test_split
X_TRAIN , X_TEST , Y_TRAIN, Y_TEST = train_test_split(X,Y, test_size =
0.25, random_state=25)
print("Size of Train X = " , len(X_TRAIN))
print("Size of Train Y = " , len(Y_TRAIN))
print("Size of Test X = " , len(X_TEST))
print("Size of Test Y = " , len(Y_TEST))
# Out:
# Size of Train X =  2331
# Size of Train Y =  2331
# Size of Test X =  778
# Size of Test Y =  778

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_TRAIN, Y_TRAIN) 
LinearRegression()
# Out:
# LinearRegression()

# %%
training_data_prediction = model.predict(X_TRAIN)
print(training_data_prediction)
# Out:
# [32.39132727 10.45869088 15.98934202 ...  7.48589413 62.11550314
#   9.37048931]

# %%
# R squared error
score_1 = metrics.r2_score(Y_TRAIN, training_data_prediction)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TRAIN, 
training_data_prediction)
print("R squared : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared :  0.897874045945255
# Mean Absolute Error :  6.995004173287811

# %%
plt.scatter(Y_TRAIN, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
y_pred = model.predict(X_TEST)
y_pred
print(y_pred)
# Out:
# [95.0206527  91.3165515  70.32901764  5.72566508 11.32914911 66.01714753
#  10.30803035 76.07296467 65.75274826 47.08171157 87.0339033  15.11381382
#  47.90386638 62.5071272  48.61004423  7.86364129 31.24013581 12.34623309
#   7.33216069 26.33308842 41.90632781 20.44771265 12.0148959  27.28533313
#  59.51482066 21.96176604 27.79273499 29.67040677 17.4117342  29.0609714
#  18.87492235 77.14484963 17.99079565 12.05232525  7.94814102 40.38756582
#  81.09841402 61.55885007 21.04948435 10.50558497 65.01068583 10.4929858
#  49.30434502  9.00387953 35.16168496 27.96107058 15.82599817 80.54611551
#  56.11129108  5.55933652 70.8291071  18.57096893  8.19431694 75.65936341
#  49.22731056 91.62924681 33.72842029  4.3679092  36.56924106 35.2485925
#   9.60122146 33.8033256  25.38663673 20.6083631  20.41346907  9.35594164
#  90.33141905 45.2651516  60.98605151 13.96909338 47.62344343 63.75326701
#   9.88563194 31.16703784  8.13463364 10.68625414 53.51754187  3.50659192
# ...

# %%
# R squared Score
score_1 = metrics.r2_score(Y_TEST, y_pred)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TEST, y_pred)
print("R squared Score : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared Score :  0.8860555790394415
# Mean Absolute Error :  7.368477098100317

# %%
plt.scatter(Y_TEST, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Preicted")
plt.show()

# %% [markdown]
# # decidsion tree

# %%
# import the regressor 
from sklearn.tree import DecisionTreeRegressor 
# create a regressor object 
regressor = DecisionTreeRegressor(random_state = 25) 
# fit the regressor with X and Y data 
regressor.fit(X_TRAIN, Y_TRAIN) 
DecisionTreeRegressor(random_state=25)
# Out:
# DecisionTreeRegressor(random_state=25)

# %%
# accuracy for prediction on training data
training_data_prediction = regressor.predict(X_TRAIN)
print(training_data_prediction)
# Out:
# [29.7029705  28.49480383 12.02802277 ... 28.49480383 63.16807938
#  28.49480383]

# %%
# R squared error
score_1 = metrics.r2_score(Y_TRAIN, training_data_prediction)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TRAIN, 
training_data_prediction)
print("R squared : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared :  1.0
# Mean Absolute Error :  7.643221791211652e-11

# %%
plt.scatter(Y_TRAIN, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
y_pred = regressor.predict(X_TEST)
y_pred
print(y_pred)
# Out:
# [9.69357071e+01 9.26568375e+01 7.06220093e+01 1.06123936e+00
#  2.84948038e+01 6.39721756e+01 1.64906943e+00 7.47248917e+01
#  6.30187836e+01 4.78965874e+01 9.09312286e+01 1.08290825e+01
#  4.60949745e+01 5.99908028e+01 4.58435707e+01 2.84948038e+01
#  2.37610836e+01 1.04712868e+01 1.01281330e-08 1.97211246e+01
#  3.83979607e+01 1.57107258e+01 1.54202318e+00 2.17342281e+01
#  6.04543648e+01 1.80948696e+01 1.76468544e+01 2.56370430e+01
#  1.13596582e+01 2.52685585e+01 1.20229082e+01 8.12633133e+01
#  1.41364613e+01 2.84948038e+01 2.84948038e+01 3.85582809e+01
#  8.50575943e+01 6.46753616e+01 1.90482464e+01 9.84929943e+00
#  6.23564529e+01 7.01171279e-01 5.62820015e+01 5.89014113e-01
#  2.84948038e+01 2.16907215e+01 6.96836329e+00 8.19862518e+01
#  5.62934113e+01 2.32830644e-09 6.84685440e+01 1.55196953e+01
#  2.84948038e+01 7.83050156e+01 5.02790298e+01 9.60750046e+01
#  2.84948038e+01 2.84948038e+01 2.84948038e+01 3.41787033e+01
# ...

# %%
# R squared Score
score_1 = metrics.r2_score(Y_TEST, y_pred)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TEST, y_pred)
print("R squared Score : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared Score :  0.9105014310787409
# Mean Absolute Error :  3.2921126956047955

# %%
plt.scatter(Y_TEST, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Preicted")
plt.show()

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=5, random_state=25)
# fit the regressor with X and Y data 
regressor.fit(X_TRAIN, Y_TRAIN) 
RandomForestRegressor(n_estimators=5, random_state=25)
# Out:
# RandomForestRegressor(n_estimators=5, random_state=25)

# %%
# accuracy for prediction on training data
training_data_prediction = regressor.predict(X_TRAIN)
print(training_data_prediction)
# Out:
# [29.58166275 28.49480383 11.93490582 ... 28.49480383 63.92421875
#  17.0968823 ]

# %%
# R squared error
score_1 = metrics.r2_score(Y_TRAIN, training_data_prediction)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TRAIN, 
training_data_prediction)
print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.9889986680430495
# Mean Absolute Error :  1.1471100489407935

# %%
plt.scatter(Y_TRAIN, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
y_pred = regressor.predict(X_TEST)
y_pred
# Out:
# array([9.67790512e+01, 9.25668839e+01, 7.03282608e+01, 6.84871458e+00,
#        2.84948038e+01, 6.41545807e+01, 1.76464202e+00, 7.36173553e+01,
#        6.29440750e+01, 4.67674133e+01, 9.02336655e+01, 1.11933708e+01,
#        4.55612907e+01, 6.01912926e+01, 4.61498451e+01, 2.27958431e+01,
#        2.40056370e+01, 2.42960616e+01, 1.70968823e+01, 2.00593548e+01,
#        3.77182938e+01, 1.52970129e+01, 1.56573915e+00, 2.15119247e+01,
#        5.88271347e+01, 1.71227459e+01, 2.17077274e+01, 2.46272518e+01,
#        1.12507631e+01, 2.57643303e+01, 1.20257126e+01, 8.06584564e+01,
#        1.36420593e+01, 1.71455875e+01, 5.69896077e+00, 3.96142288e+01,
#        8.49992874e+01, 6.45660728e+01, 1.87788261e+01, 1.73075012e+01,
#        6.19662521e+01, 7.36215627e-01, 5.09953369e+01, 5.94111618e+00,
#        2.84948038e+01, 2.37493221e+01, 6.87155666e+00, 8.18509872e+01,
#        5.66094215e+01, 2.27958431e+01, 6.86285431e+01, 1.54333065e+01,
# ...

# %%
# R squared Score
score_1 = metrics.r2_score(Y_TEST, y_pred)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TEST, y_pred)
print("R squared Score : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared Score :  0.9462934623862214
# Mean Absolute Error :  3.320392462350758

# %%
plt.scatter(Y_TEST, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Preicted")
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
# Assuming regressor is your trained Random Forest model
# Pick one tree from the forest, e.g., the first tree (index 0)
tree_to_plot = regressor.estimators_[0]
# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(tree_to_plot, feature_names=Maliha.columns.tolist(),filled=True, rounded=True, fontsize=10)
plt.title("Decision Tree from Random Forest")
plt.show()

# %% [markdown]
# # SVM REGRESSION

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear') 
svr.fit(X_TRAIN, Y_TRAIN) 
SVR(kernel='linear')
# Out:
# SVR(kernel='linear')

# %%
# accuracy for prediction on training data
training_data_prediction = svr.predict(X_TRAIN)
print(training_data_prediction)
# Out:
# [137.42975042  58.86472974 130.36995576 ... 197.1679003  -36.11048998
#  119.13785849]

# %%
# R squared error
score_1 = metrics.r2_score(Y_TRAIN, training_data_prediction)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TRAIN, 
training_data_prediction)
print("R squared : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared :  -17.616305262156228
# Mean Absolute Error :  93.36800812191629

# %%
plt.scatter(Y_TRAIN, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
y_pred = svr.predict(X_TEST)
y_pred
print(y_pred)
# Out:
# [ 2.94964168e+01  4.49652921e+01  3.21164267e+01  1.47410222e+02
#  -9.57633672e+01  3.53172647e+01  1.23057775e+02  4.70944971e+01
#  -1.09925828e+02  2.29058701e+02  9.84571348e+01  1.07297771e+02
#   1.08818403e+02  2.93270575e+02  1.05616588e+02  8.97974133e+01
#   9.63473969e+01  1.10497173e+02  3.30219337e+02  1.32182215e+02
#   6.76158600e+01  1.22105752e+02  3.83828158e+01  1.94883090e+02
#  -2.33314092e+01 -1.52698493e+01 -8.64650525e+01  8.88906451e+01
#   3.30120551e+01  1.24354662e+02  1.44811916e+01  7.98158403e+01
#   1.44550132e+01  1.21627806e+02  1.44928278e+02  1.32643609e+02
#   2.12714297e+02  1.07214920e+02  1.68334921e+02  1.37343505e+02
#   1.15543832e+02  7.29319378e+01  3.26822285e+02  1.48888137e+02
#   9.91532970e+01  1.35094599e+02  8.76258989e+01  6.18487857e+01
#   3.37396138e+01  4.19629190e+00 -7.69283395e+01  2.11409480e+02
#   5.23025166e+01  6.04184397e+01  9.57341929e+01  1.00408558e+02
# ...

# %%
# R squared Score
score_1 = metrics.r2_score(Y_TEST, y_pred)
# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_TEST, y_pred)
print("R squared Score : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared Score :  -16.815578647954876
# Mean Absolute Error :  92.4333429065473

# %%
plt.scatter(Y_TEST, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Preicted")
plt.show()
