# %%
# Q NO 1   PRINT STRING
result='*'*5+'\n'+'*'*4+'\n'+'*'*3+'\n'+'*'*2+'\n'+'*'
print(result+'\n'+result[ ::-1])
# Out:
# *****
# ****
# ***
# **
# *
# *
# **
# ***
# ****
# *****

# %%
# Q NO 2
num1=input('enter your nam:')
num2=input('enter your age:')
num3=input('enter your reg no:')
num4=input('enter your town:')
num5=input('enter your uni:')
num6=input('enter your deg:')
result='my name is '+ num1 + '.my age is '+ num2 + '.my ag no is '+num3 + '.my home adress is '+num4 + '.my name is '+num5 + '.my degree is '+num6
print(result)
# Out:
# enter your nam: sana
# enter your age: 33
# enter your reg no: 7113
# enter your town: BB block
# enter your uni: uaf
# enter your deg: bscs
# my name is sana.my age is 33.my ag no is 7113.my home adress is BB block.my name is uaf.my degree is bscs

# %%
  # length
print(len(result))
# Out:
# 105

# %%
print(result.upper())
# Out:
# MY NAME IS SANA.MY AGE IS 33.MY AG NO IS 7113.MY HOME ADRESS IS BB BLOCK.MY NAME IS UAF.MY DEGREE IS BSCS

# %%
print(result.lower())
# Out:
# my name is sana.my age is 33.my ag no is 7113.my home adress is bb block.my name is uaf.my degree is bscs

# %%
 # reverse order
print(result[ ::-1])
# Out:
# scsb si eerged ym.fau si eman ym.kcolb BB si sserda emoh ym.3117 si on ga ym.33 si ega ym.anas si eman ym

# %%
print(result[ :: -2])
# Out:
# ss iere mfus mny.cl Bs sraeo m31 io ay.3s g maa iea m

# %%
print(result[ ::-3])
# Out:
# sbieeyf  ayklBssr oy37inam3igyasim

# %%
# Q no 3
import cmath
a=float(input('enter your no'))
b=float(input('enter your no'))
c=float(input('enter your no'))
d=b**2-4*a*c
x1=(-b + cmath.sqrt(d))/(2*a)
x2=(-b - cmath.sqrt(d))/(2*a)
print(x1)
print(x2)
# Out:
# enter your no 10
# enter your no 20
# enter your no 40
# (-1+1.7320508075688774j)
# (-1-1.7320508075688774j)

# %%
# Q NO 4
m=float(input('enter your no'))
c=float(input('enter your no'))
E=m*c**2
print(E)
# Out:
# enter your no 10
# enter your no 20
# 4000.0

# %%
# Q no 5
alpha='ABCDEFGHIJKLMNOPQRSTUVWXYZ'
# PRINT REVERSR ORDER
print(alpha[ ::-1])
# Out:
# ZYXWVUTSRQPONMLKJIHGFEDCBA

# %%
# steps size 2
print(alpha[ ::-2])
# Out:
# ZXVTRPNLJHFDB

# %%
# step size 3
print(alpha[ ::3])
# Out:
# ADGJMPSVY

# %%
# reverse with step size 3
print(alpha[ ::-3])
# Out:
# ZWTQNKHEB

# %%
# replace

print("***"+alpha[ 1:-1:]+"***")
# Out:
# ***BCDEFGHIJKLMNOPQRSTUVWXY***

# %%
# Q NO 6
rows=6
cols=22
for i in range(rows):
  print("\\" * (i*2)+ "!" *(cols-4* (i))+ "/" *(i*2) )
# Out:
# !!!!!!!!!!!!!!!!!!!!!!
# \\!!!!!!!!!!!!!!!!!!//
# \\\\!!!!!!!!!!!!!!////
# \\\\\\!!!!!!!!!!//////
# \\\\\\\\!!!!!!////////
# \\\\\\\\\\!!//////////

# %%
# Q NO 7
print('1234567890'*9)
# Out:
# 123456789012345678901234567890123456789012345678901234567890123456789012345678901234567890
